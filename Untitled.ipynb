# %%
import pandas as pd

# %%
df = pd.read_json('task_input_list.json')

# %%
df.head(50)
# Out:
#                                                     0
# 0                                            ABC BANK
# 1                                   Preferred Rewards
# 2                                      P.O. Box 12345
# 3                        Customer service information
# 4                               Wilmington, DE 144444
# 5                                                   0
# 6                                  ph: (555) 555-1234
# 7             TDD/TTY users only call: (800) 555-1234
# 8                               other: 1-800-555-1234
# 9                                            John Doe
# 10                                bankingservices.com
# 11                              Your Adv Plus Banking
# 12                         Preferred Rewards Platinum
# 13         for November 27, 2018 to December 24, 2018
# 14                                    Account summary
# 15             Beginning balance on November 27, 2018
# ...

# %%
cll_df = df[df[0].str.contains(r"\bpoint\b", case = False)]

# %%
cll_df.head()
# Out:
#                                                     0
# 49  point-of-sale transactions) on the statement o...

# %%
amt = pd.read_excel("out.xlsx", 'Withdrawals')

# %%
amt.head(5)
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0   11/30/18          30          11          18
# 1   12/03/18           3          12          18
# 2   12/04/18           4          12          18
# 3   12/07/18           7          12          18
# 4   12/11/18          11          12          18
#
#                                           Unnamed: 4  Unnamed: 5
# 0  Automatic Transfer to SAV 2084 Confirmation# 1...      -25.00
# 1  Online Banking payment to CRD 8610 Confirmatio...     -200.00
# 2                          Customer Withdrawal Image  -12,000.00
# 3                                          TRANSFER    -3,695.00
# 4  CARFAXDES:BT1210 ID:000000071591462 INDN:CO ID...     -399.98

# %%
xls = pd.ExcelFile('out.xlsx')
df2 = pd.read_excel(xls, 'Withdrawals')
df1 = pd.read_excel(xls, 'Deposit')

# %%
df1.head(7)
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0   12/03/18           3          12          18
# 1   12/10/18          10          12          18
# 2   12/21/18          21          12          18
# 3   12/24/18          24          12          18
#
#                                     Unnamed: 4    Amount
# 0                               Counter Credit  8,075.00
# 1                               Counter Credit  9,970.00
# 2  PAYPALDES:TRANSFER ID:1004561753452 INDN:CO  1,000.00
# 3                               Counter Credit  8,405.00

# %%
maxa = max(df1['Amount'])
mini = min(df2['Amount'])
mini
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-06c44fc8e964> in <module>
#       1 maxa = max(df1['Amount'])
# ----> 2 mini = min(df2['Amount'])
#       3 mini
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
maxa
# Out:
# '9,970.00'
